# %%
# Keywords

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# No of keyword 

import keyword
print(len(keyword.kwlist))
# Out:
# 35

# %%
# Datatype

# %%
# int
a=10
print(a)
print(type(a)

# %%
# we can print very large no of value

b=16247867646627768991783417187
print(b)
# Out:
# 16247867646627768991783417187

# %%
# Conversion

# %%
# Decimal to Binary

a=21
print(bin(a))
# Out:
# 0b10101

# %%
# Octal to Binary

a=0o123
print(bin(a))
# Out:
# 0b1010011

# %%
# Decimal to Octal

c=120
print(oct(c))
# Out:
# 0o170

# %%
# Binary to Octal

d=0b1010
print(oct(d))
# Out:
# 0o12

# %%
# Decimal to  Hexadecimal

e=198
print(hex(e))
# Out:
# 0xc6

# %%
# Octal to Hexadecimal

f=0o125
print(hex(f))
# Out:
# 0x55

# %%
# Float 

a=90.5
print(a)
print(type(a))
# Out:
# 90.5
# <class 'float'>

# %%
# Addition of int and float

a=10.3+30
print(a)
sal=4.5e4000
print(sal)
# Out:
# 40.3
# inf

# %%
# Multiplication of int and float

a=10.3*30
print(a)
# Out:
# 309.0

# %%
# Boolean

a=50
a_is_integer= True
print(a)
print(type(a_is_integer))
# Out:
# 50
# <class 'bool'>

# %%
name = "Abakash"
age=22
reg_no=22

print(age==reg_no)

print(id(name))
print(id(age))
print(id(reg_no))
# Out:
# True
# 2063714486832
# 140730979096008
# 140730979096008

# %%
# Deletion of variable

v=19
print(v)
del v
print(v)
# Out:
# 19
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 print(v)
#       3 del v
# ----> 4 print(v)
#
# NameError: name 'v' is not defined

# %%
name = "Abakash"
age_=23
regn_no=23

del regn_no

print(age_)
print(regn_no)
# Out:
# 23
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       5 del regn_no
#       7 print(age_)
# ----> 8 print(regn_no)
#
# NameError: name 'regn_no' is not defined

# %%
name = "Abakash"
age_=23
regn_no=23

del age_

print(age_)
print(regn_no)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 regn_no=23
#       5 del age_
# ----> 7 print(age_)
#       8 print(regn_no)
#
# NameError: name 'age_' is not defined
