# %%
print("Hello Numpy")
# Out:
# Hello Numpy

# %%
# Printing Variables
x=100
print(x)
x=120
print(x)
# Out:
# 100
# 120

# %%
# operation on a single variable
a=100
print(a+a)
print(a*a)
print(a/a) # it will return output in float
print(a-a)
# Out:
# 200
# 10000
# 1.0
# 0

# %%
# add two number store inside third varible

a=100
b=34
c=a+b
print(c)
# Out:
# 134

# %%
# We have to assign a value to variable otherwise it will show(NameError)
a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a
#       2 print(a)
#
# NameError: name 'a' is not defined

# %%
c=100
print(c)
c=100.0
print(c)
# Out:
# 100
# 100.0

# %%
# By assigning none we can create a variable and later we can update
b=None
print(b)
# Out:
# None

# %%
# type of variable
x=1000
print(id(x))
print(type(x))
# Out:
# 2261652576880
# <class 'int'>

# %%
#variable is case sensitive
x=100
X=x+100
print(x)
print(X)
# Out:
# 100
# 200

# %%
v=100
V=V+100
print(v)
print(V)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 v=100
# ----> 2 V=V+100
#       3 print(v)
#       4 print(V)
#
# NameError: name 'V' is not defined
