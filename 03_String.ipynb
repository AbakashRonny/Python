# %%
#String

# %%
name='Abakash'
print(name)
print(type(name))
# Out:
# Abakash
# <class 'str'>

# %%
# We can use ''  ""  ''''''  """"""

# %%
# Multiline string

# %%
Address="""
     Town:Pipili
     pin:752102
     Dist:Puri
"""

print(Address)
# Out:
#      Town:Pipili
#      pin:752102
#      Dist:Puri

# %%
Address="""
"""

print(len(Address))    #One length is added for nextline
# Out:
# 1

# %%
Address="""
Town:Pipili
"""

print(len(Address))
# Out:
# 13

# %%
Address="""
Town:Pipili
pin:752102
Dist:Puri
"""

print(len(Address))
# Out:
# 34

# %%
# accessing the value of a string using index
name='Abakash'

print(name)
print(name[0])
print(name[1])
print(name[-1])
print(name[-6])
print(name[-7])
# Out:
# Abakash
# A
# b
# h
# b
# A

# %%
name='Abakash'

print(name)
print(id(name[0]))
print(id(name[-7]))
print(id(name[1]))
print(id(name[-6]))
# Out:
# Abakash
# 140731007123456
# 140731007123456
# 140731007125304
# 140731007125304

# %%
# accessing element using slice

# %%
name='Abakash'

print(name[: :1])
print(name[1:5:2])
# Out:
# Abakash
# bk

# %%
name='Abakash'
print(name[: :-1])
# Out:
# hsakabA

# %%
# string concatition
name='Abakash'
age=21

print(name+age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 name='Abakash'
#       2 age=21
# ----> 4 print(name+age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name='Abakash'
age='21'

print(name+age)
# Out:
# Abakash21

# %%
# updation
name='Abakash'
print(id(name))
print(id(name[0]))

name='Abinash'

print(id(name[0]))
print(name)
print(id(name))
# Out:
# 2746628396720
# 140715888623616
# 140715888623616
# Abinash
# 2744494163248

# %%
# value assignment
name3='Abakasd'

name3[-1]='h'

print(name3)
print(name3[-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 name3='Abakasd'
# ----> 3 name3[-1]='h'
#       5 print(name3)
#       6 print(name3[-1])
#
# TypeError: 'str' object does not support item assignment
